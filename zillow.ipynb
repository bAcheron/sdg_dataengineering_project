# %% [markdown]
# $SeattleDataGuy2021
#
# Your Zillow Web Services Identification (ZWSID) is: X1-ZWz1idyacab4ej_2ninr

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# from pyzillow.pyzillow import ZillowWrapper
# zillow_data = ZillowWrapper(KEY)

# %%
import os, sys, time
working_dir = 'H:/UGA MASTERS/SDG/zillow'
os.chdir(working_dir)

import pyautogui
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import pandas as pd
from termcolor import colored
from project_tools import load_obj, interact
from bs4 import BeautifulSoup

city = 'wookstock'
state = 'GA'

# %%
url = f'https://www.zillow.com/homes/{city},-{state}_rb/'

# %%
driver = webdriver.Chrome()
driver.get(url)

# %%
x = 500
while x < 10000:
    time.sleep(0.5)
    driver.execute_script(f"window.scrollTo(0, {x});")
    x = x + 1000

# %%
html = driver.page_source
soup = BeautifulSoup(html)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-67-bb02237c8813> in <module>
# ----> 1 html = driver.page_source
#       2 soup = BeautifulSoup(html)
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ...

# %%
soup.find_all("div", class_="list-card-price")
# Out:
# [<div class="list-card-price">$395,000</div>,
#  <div class="list-card-price">$395,000</div>,
#  <div class="list-card-price">$572,900+</div>,
#  <div class="list-card-price">$260,000</div>,
#  <div class="list-card-price">$--</div>,
#  <div class="list-card-price">$474,900</div>,
#  <div class="list-card-price">$319,900</div>,
#  <div class="list-card-price">$420,000</div>,
#  <div class="list-card-price">$350,000</div>,
#  <div class="list-card-price">$709,995+</div>,
#  <div class="list-card-price">$375,000</div>,
#  <div class="list-card-price">$420,000</div>,
#  <div class="list-card-price">$882,900+</div>,
#  <div class="list-card-price">$474,900</div>,
#  <div class="list-card-price">$279,900</div>,
#  <div class="list-card-price">$297,900</div>,
#  <div class="list-card-price">$475,000</div>,
#  <div class="list-card-price">$475,000</div>,
#  <div class="list-card-price">$416,900+</div>,
#  <div class="list-card-price">$416,900+</div>,
# ...

# %%
soup.find_all("div", class_="list-card-price")
# Out:
# [<div class="list-card-price">$395,000</div>,
#  <div class="list-card-price">$395,000</div>,
#  <div class="list-card-price">$572,900+</div>,
#  <div class="list-card-price">$260,000</div>,
#  <div class="list-card-price">$--</div>,
#  <div class="list-card-price">$474,900</div>,
#  <div class="list-card-price">$319,900</div>,
#  <div class="list-card-price">$420,000</div>,
#  <div class="list-card-price">$350,000</div>,
#  <div class="list-card-price">$709,995+</div>,
#  <div class="list-card-price">$375,000</div>,
#  <div class="list-card-price">$420,000</div>,
#  <div class="list-card-price">$882,900+</div>,
#  <div class="list-card-price">$474,900</div>,
#  <div class="list-card-price">$279,900</div>,
#  <div class="list-card-price">$297,900</div>,
#  <div class="list-card-price">$475,000</div>,
#  <div class="list-card-price">$475,000</div>,
#  <div class="list-card-price">$416,900+</div>,
#  <div class="list-card-price">$416,900+</div>,
# ...
